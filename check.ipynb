# %%
data = {
    "file": "..."
}

# %%
import requests


url = "https://conneqtion-ocr-api-production.up.railway.app/api/conneqtion/convert/pdf/png"

# Data you want to send in the POST request


# Optional headers
headers = {
    "Content-Type": "application/json"
}

# Send the POST request
response = requests.post(url, json=data, headers=headers)

# Check the response status code
if response.status_code == 200:
    print("POST request successful!")
    # Process the response data as needed
    print(response.json())
else:
    print("POST request failed with status code:", response.status_code)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import requests
#       4 url = "https://conneqtion-ocr-api-production.up.railway.app/api/conneqtion/convert/pdf/png"
#       6 # Data you want to send in the POST request
#       7
#       8
#       9 # Optional headers
#
# ModuleNotFoundError: No module named 'requests'
